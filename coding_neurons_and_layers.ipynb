# %% [markdown]
# <a href="https://colab.research.google.com/github/ANNON17-byte/ANNON17-byte/blob/main/coding_neurons_and_layers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3 - Input Neuron

# %%
inputs = [1, 2, 3]
weights = [0.2, 0.8, -0.5]
bias = 2

output = inputs[0]*we
